# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from datetime import datetime, timedelta

# import all libraries and dependencies for data visualization
pd.options.display.float_format='{:.4f}'.format
plt.rcParams['figure.figsize'] = [8,8]
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', -1) 
sns.set(style='darkgrid')
import matplotlib.ticker as ticker
import matplotlib.ticker as plticker

# import all libraries and dependencies for machine learning
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.base import TransformerMixintest
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import statsmodels.api as sm
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import r2_score
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [115], in <cell line: 21>()
#      19 from sklearn.model_selection import train_test_split
#      20 from sklearn import preprocessing
# ---> 21 from sklearn.base import TransformerMixintest
#      22 from sklearn.model_selection import train_test_split
#      23 from sklearn.preprocessing import MinMaxScaler
#
# ImportError: cannot import name 'TransformerMixintest' from 'sklearn.base' (d:\sw\anaconda3\lib\site-packages\sklearn\base.py)

# %%
file = 'train_data.csv'

# %%
df=pd.read_csv(file)

# %%
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0     Maruti Wagon R LXI CNG            Mumbai      2010  72000
# 1     Hyundai Creta 1.6 CRDi SX Option  Pune        2015  41000
# 2     Honda Jazz V                      Chennai     2011  46000
# 3     Maruti Ertiga VDI                 Chennai     2012  87000
# 4     Audi A4 New 2.0 TDI Multitronic   Coimbatore  2013  40670
# ...                               ...          ...   ...    ...
# 3494  Hyundai Verna 1.6 SX              Hyderabad   2012  83678
# 3495  Maruti Wagon R LXI BS IV          Pune        2010  91000
# 3496  Maruti Ertiga SHVS ZDI Plus       Jaipur      2016  50000
# 3497  Hyundai Xcent 1.1 CRDi S Option   Delhi       2015  58000
# 3498  Maruti Swift VDI                  Jaipur      2012  80000
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  \
# 0     CNG       Manual       First      26.6 km/kg  998 CC   58.16 bhp
# 1     Diesel    Manual       First      19.67 kmpl  1582 CC  126.2 bhp
# 2     Petrol    Manual       First      18.2 kmpl   1199 CC  88.7 bhp
# 3     Diesel    Manual       First      20.77 kmpl  1248 CC  88.76 bhp
# 4     Diesel    Automatic    Second     15.2 kmpl   1968 CC  140.8 bhp
# ...      ...          ...       ...           ...       ...        ...
# 3494  Diesel    Manual       First      22.32 kmpl  1582 CC  126.32 bhp
# 3495  Petrol    Manual       First      18.9 kmpl   998 CC   67.1 bhp
# 3496  Diesel    Manual       First      24.52 kmpl  1248 CC  88.5 bhp
# 3497  Diesel    Manual       First      24.4 kmpl   1120 CC  71.01 bhp
# 3498  Diesel    Manual       First      22.9 kmpl   1248 CC  74 bhp
#
#       Seats  New_Price   Price
# 0    5.0000  NaN       1.7500
# 1    5.0000  NaN       12.5000
# 2    5.0000  8.61 Lakh 4.5000
# 3    7.0000  NaN       6.0000
# 4    5.0000  NaN       17.7400
# ...     ...  ...           ...
# 3494 5.0000  NaN       5.5000
# 3495 5.0000  NaN       2.3000
# 3496 7.0000  NaN       8.7000
# 3497 5.0000  NaN       4.9500
# 3498 5.0000  NaN       4.2500
#
# [3499 rows x 13 columns]

# %%
df.shape
# Out:
# (3499, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3499 entries, 0 to 3498
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               3499 non-null   object
#  1   Location           3499 non-null   object
#  2   Year               3499 non-null   int64
#  3   Kilometers_Driven  3499 non-null   int64
#  4   Fuel_Type          3499 non-null   object
#  5   Transmission       3499 non-null   object
#  6   Owner_Type         3499 non-null   object
#  7   Mileage            3499 non-null   object
#  8   Engine             3477 non-null   object
#  9   Power              3477 non-null   object
#  10  Seats              3474 non-null   float64
#  11  New_Price          481 non-null    object
#  12  Price              3499 non-null   float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 355.5+ KB

# %%
df['Mileage'] = df['Mileage'].apply(lambda x: str(x).replace('kmpl', '').replace('km/kg', '')).astype(float)



df['Engine'] = df['Engine'].apply(lambda x: str(x).replace('CC', '')).astype(float)

df['Power'] = df['Power'].apply(lambda x: str(x).replace('bhp', '').replace('null ', '0')).astype(float)

df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0     Maruti Wagon R LXI CNG            Mumbai      2010  72000
# 1     Hyundai Creta 1.6 CRDi SX Option  Pune        2015  41000
# 2     Honda Jazz V                      Chennai     2011  46000
# 3     Maruti Ertiga VDI                 Chennai     2012  87000
# 4     Audi A4 New 2.0 TDI Multitronic   Coimbatore  2013  40670
# ...                               ...          ...   ...    ...
# 3494  Hyundai Verna 1.6 SX              Hyderabad   2012  83678
# 3495  Maruti Wagon R LXI BS IV          Pune        2010  91000
# 3496  Maruti Ertiga SHVS ZDI Plus       Jaipur      2016  50000
# 3497  Hyundai Xcent 1.1 CRDi S Option   Delhi       2015  58000
# 3498  Maruti Swift VDI                  Jaipur      2012  80000
#
#      Fuel_Type Transmission Owner_Type  Mileage    Engine    Power  Seats  \
# 0     CNG       Manual       First     26.6000  998.0000  58.1600  5.0000
# 1     Diesel    Manual       First     19.6700  1582.0000 126.2000 5.0000
# 2     Petrol    Manual       First     18.2000  1199.0000 88.7000  5.0000
# 3     Diesel    Manual       First     20.7700  1248.0000 88.7600  7.0000
# 4     Diesel    Automatic    Second    15.2000  1968.0000 140.8000 5.0000
# ...      ...          ...       ...        ...        ...      ...    ...
# 3494  Diesel    Manual       First     22.3200  1582.0000 126.3200 5.0000
# 3495  Petrol    Manual       First     18.9000  998.0000  67.1000  5.0000
# 3496  Diesel    Manual       First     24.5200  1248.0000 88.5000  7.0000
# 3497  Diesel    Manual       First     24.4000  1120.0000 71.0100  5.0000
# 3498  Diesel    Manual       First     22.9000  1248.0000 74.0000  5.0000
#
#       New_Price   Price
# 0     NaN       1.7500
# 1     NaN       12.5000
# 2     8.61 Lakh 4.5000
# 3     NaN       6.0000
# 4     NaN       17.7400
# ...   ...           ...
# 3494  NaN       5.5000
# 3495  NaN       2.3000
# 3496  NaN       8.7000
# 3497  NaN       4.9500
# 3498  NaN       4.2500
#
# [3499 rows x 13 columns]

# %%
sns.heatmap(df.corr(), annot = True)
plt.show()

# %%
sns.heatmap(df1.corr(), annot = True)
plt.show()

# %%
df=df.drop(["Location"], axis='columns')

# %%
df
# Out:
#                                   Name  Year  Kilometers_Driven Fuel_Type  \
# 0     Maruti Wagon R LXI CNG            2010  72000              CNG
# 1     Hyundai Creta 1.6 CRDi SX Option  2015  41000              Diesel
# 2     Honda Jazz V                      2011  46000              Petrol
# 3     Maruti Ertiga VDI                 2012  87000              Diesel
# 4     Audi A4 New 2.0 TDI Multitronic   2013  40670              Diesel
# ...                               ...    ...    ...                 ...
# 3494  Hyundai Verna 1.6 SX              2012  83678              Diesel
# 3495  Maruti Wagon R LXI BS IV          2010  91000              Petrol
# 3496  Maruti Ertiga SHVS ZDI Plus       2016  50000              Diesel
# 3497  Hyundai Xcent 1.1 CRDi S Option   2015  58000              Diesel
# 3498  Maruti Swift VDI                  2012  80000              Diesel
#
#      Transmission Owner_Type  Mileage    Engine    Power  Seats  New_Price  \
# 0     Manual       First     26.6000  998.0000  58.1600  5.0000  NaN
# 1     Manual       First     19.6700  1582.0000 126.2000 5.0000  NaN
# 2     Manual       First     18.2000  1199.0000 88.7000  5.0000  8.61 Lakh
# 3     Manual       First     20.7700  1248.0000 88.7600  7.0000  NaN
# 4     Automatic    Second    15.2000  1968.0000 140.8000 5.0000  NaN
# ...         ...       ...        ...        ...      ...    ...  ...
# 3494  Manual       First     22.3200  1582.0000 126.3200 5.0000  NaN
# 3495  Manual       First     18.9000  998.0000  67.1000  5.0000  NaN
# 3496  Manual       First     24.5200  1248.0000 88.5000  7.0000  NaN
# 3497  Manual       First     24.4000  1120.0000 71.0100  5.0000  NaN
# 3498  Manual       First     22.9000  1248.0000 74.0000  5.0000  NaN
#
#        Price
# 0    1.7500
# 1    12.5000
# 2    4.5000
# 3    6.0000
# 4    17.7400
# ...      ...
# 3494 5.5000
# 3495 2.3000
# 3496 8.7000
# 3497 4.9500
# 3498 4.2500
#
# [3499 rows x 12 columns]

# %%
df.isna()
# Out:
#        Name   Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0     False  False  False              False      False         False
# 1     False  False  False              False      False         False
# 2     False  False  False              False      False         False
# 3     False  False  False              False      False         False
# 4     False  False  False              False      False         False
# ...     ...    ...    ...                ...        ...           ...
# 3494  False  False  False              False      False         False
# 3495  False  False  False              False      False         False
# 3496  False  False  False              False      False         False
# 3497  False  False  False              False      False         False
# 3498  False  False  False              False      False         False
#
#       Mileage  Engine  Power  Seats  New_Price  Price
# 0     False    False   False  False  True       False
# 1     False    False   False  False  True       False
# 2     False    False   False  False  False      False
# 3     False    False   False  False  True       False
# 4     False    False   False  False  True       False
# ...     ...      ...     ...    ...   ...         ...
# 3494  False    False   False  False  True       False
# 3495  False    False   False  False  True       False
# 3496  False    False   False  False  True       False
# 3497  False    False   False  False  True       False
# 3498  False    False   False  False  True       False
#
# [3499 rows x 12 columns]

# %%
df=df.drop("New_Price", axis=1)

# %%
df.isnull()
# Out:
#        Name   Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0     False  False  False              False      False         False
# 1     False  False  False              False      False         False
# 2     False  False  False              False      False         False
# 3     False  False  False              False      False         False
# 4     False  False  False              False      False         False
# ...     ...    ...    ...                ...        ...           ...
# 3494  False  False  False              False      False         False
# 3495  False  False  False              False      False         False
# 3496  False  False  False              False      False         False
# 3497  False  False  False              False      False         False
# 3498  False  False  False              False      False         False
#
#       Mileage  Engine  Power  Seats  Price
# 0     False    False   False  False  False
# 1     False    False   False  False  False
# 2     False    False   False  False  False
# 3     False    False   False  False  False
# 4     False    False   False  False  False
# ...     ...      ...     ...    ...    ...
# 3494  False    False   False  False  False
# 3495  False    False   False  False  False
# 3496  False    False   False  False  False
# 3497  False    False   False  False  False
# 3498  False    False   False  False  False
#
# [3499 rows x 11 columns]

# %%
df.dtypes
# Out:
# Name                 object
# Year                 int64
# Kilometers_Driven    int64
# Fuel_Type            object
# Transmission         object
# Owner_Type           object
# Mileage              float64
# Engine               float64
# Power                float64
# Seats                float64
# Price                float64
# dtype: object

# %%
#value ranges from 5 to 15 L..

# %%
# Segregation of Numerical and Categorical Variables/Columns

cat_col = df.select_dtypes(include=['object']).columns
num_col = df.select_dtypes(exclude=['object']).columns
df_cat = df[cat_col]
df_num = df[num_col]

# %%
# # Visualizing the different car names available

# plt.rcParams['figure.figsize'] = [15,8]
# ax=df['Name'].value_counts().plot(kind='bar',stacked=True, colormap = 'Set1')
# # ax.set_text('CarName')
# plt.xlabel("Names of the Car",fontweight = 'bold')
# plt.ylabel("Count of Cars",fontweight = 'bold')

plt.figure(figsize=(8,8))

plt.title('Car Price Distribution Plot')
sns.distplot(df['Price'])
# Out:
# <AxesSubplot:title={'center':'Car Price Distribution Plot'}, xlabel='Price', ylabel='Density'>

# %%
# plt.figure(figsize=(20, 15))
# plt.subplot(3,3,1)
# sns.boxplot(x = 'Transmission', y = 'Price', data = df)
# plt.subplot(3,3,2)
# sns.boxplot(x = 'Fuel_Type', y = 'Price', data = df)
# plt.subplot(3,3,3)
# sns.boxplot(x = 'Owner_Type', y = 'Price', data = df)


# plt.show()

# %%
scaler = preprocessing.StandardScaler()

df_num  = scaler.fit_transform(df_num )
df
# Out:
#                                   Name  Year  Kilometers_Driven Fuel_Type  \
# 0     Maruti Wagon R LXI CNG            2010  72000              CNG
# 1     Hyundai Creta 1.6 CRDi SX Option  2015  41000              Diesel
# 2     Honda Jazz V                      2011  46000              Petrol
# 3     Maruti Ertiga VDI                 2012  87000              Diesel
# 4     Audi A4 New 2.0 TDI Multitronic   2013  40670              Diesel
# ...                               ...    ...    ...                 ...
# 3494  Hyundai Verna 1.6 SX              2012  83678              Diesel
# 3495  Maruti Wagon R LXI BS IV          2010  91000              Petrol
# 3496  Maruti Ertiga SHVS ZDI Plus       2016  50000              Diesel
# 3497  Hyundai Xcent 1.1 CRDi S Option   2015  58000              Diesel
# 3498  Maruti Swift VDI                  2012  80000              Diesel
#
#      Transmission Owner_Type  Mileage    Engine    Power  Seats   Price
# 0     Manual       First     26.6000  998.0000  58.1600  5.0000 1.7500
# 1     Manual       First     19.6700  1582.0000 126.2000 5.0000 12.5000
# 2     Manual       First     18.2000  1199.0000 88.7000  5.0000 4.5000
# 3     Manual       First     20.7700  1248.0000 88.7600  7.0000 6.0000
# 4     Automatic    Second    15.2000  1968.0000 140.8000 5.0000 17.7400
# ...         ...       ...        ...        ...      ...    ...     ...
# 3494  Manual       First     22.3200  1582.0000 126.3200 5.0000 5.5000
# 3495  Manual       First     18.9000  998.0000  67.1000  5.0000 2.3000
# 3496  Manual       First     24.5200  1248.0000 88.5000  7.0000 8.7000
# 3497  Manual       First     24.4000  1120.0000 71.0100  5.0000 4.9500
# 3498  Manual       First     22.9000  1248.0000 74.0000  5.0000 4.2500
#
# [3499 rows x 11 columns]

# %%
# sig_cat_col = ['Name', 'Fuel_Type','Transmission','Owner_Type']

# %%
# df1=df
# df1

# %%
# dummies = pd.get_dummies(df1[sig_cat_col])
# dummies.shape

# %%
# dummies = pd.get_dummies(df1[sig_cat_col], drop_first = True)
# dummies.shape

# %%
# df1 = pd.concat([df1, dummies], axis = 1)

# %%
# df1.drop( sig_cat_col, axis = 1, inplace = True)
# df1.shape

# %%
# df=df.drop("New_Price", axis=1)
# df=df.drop("P[rice", axis=1)
# df

# Defining the map function
def dummies(x,df):
    temp = pd.get_dummies(df[x], drop_first = True)
    df = pd.concat([df, temp], axis = 1)
    df.drop([x], axis = 1, inplace = True)
    return df
# Applying the function to the cars_lr

df = dummies('Fuel_Type',df)
df = dummies('Transmission',df)
df = dummies('Owner_Type',df)

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.fillna(999, inplace=True)

# %%
# scaler = preprocessing.StandardScaler()
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

num_vars = ['Year', 'Kilometers_Driven', 'Mileage', 'Engine', 'Power','Seats','Price']

df[num_vars] = scaler.fit_transform(df[num_vars])

# %%
np.random.seed(0)

# %%
# df_train, df_test = train_test_split(df, train_size = 0.8, test_size = 0.2, random_state = 100)

# %%
X = df.drop("Price", axis=1)
y = df["Price"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,
                                                   random_state=2)

# %%
X_train.head()
# Out:
#                                      Name    Year  Kilometers_Driven  Mileage  \
# 829   Toyota Etios Liva G                 -0.4262 -0.2601            0.0471
# 2535  Maruti Swift Dzire Vdi BSIV         0.8148  0.0793             0.2646
# 1708  Audi Q3 35 TDI Quattro Premium Plus 0.8148  -0.0098            -0.6337
# 1589  Mahindra Bolero ZLX                 -0.1160 0.0276             -0.4619
# 1536  Volkswagen Vento Diesel Highline    -0.7365 -0.0844            0.5342
#
#       Engine   Power   Seats  Diesel  LPG  Petrol  Manual  Fourth & Above  \
# 829  -0.7143 -1.3154 -0.0883  0       0    1       1       0
# 2535 -0.6279 -0.4845 -0.0883  1       0    0       1       0
# 1708 0.5929  0.7198  -0.0883  1       0    0       0       0
# 1589 1.5339  -0.6171 -0.0644  1       0    0       1       0
# 1536 -0.0344 -0.1505 -0.0883  1       0    0       1       0
#
#       Second  Third
# 829   0       0
# 2535  0       0
# 1708  0       0
# 1589  0       0
# 1536  0       0

# %%
# # Apply scaler() to all the columns except the 'dummy' variables
# import warnings
# warnings.filterwarnings("ignore")

# df_train[sig_num_col] = scaler.fit_transform(df_train[sig_num_col])

# %%
X_train.head()
# Out:
#                                      Name    Year  Kilometers_Driven  Mileage  \
# 829   Toyota Etios Liva G                 -0.4262 -0.2601            0.0471
# 2535  Maruti Swift Dzire Vdi BSIV         0.8148  0.0793             0.2646
# 1708  Audi Q3 35 TDI Quattro Premium Plus 0.8148  -0.0098            -0.6337
# 1589  Mahindra Bolero ZLX                 -0.1160 0.0276             -0.4619
# 1536  Volkswagen Vento Diesel Highline    -0.7365 -0.0844            0.5342
#
#       Engine   Power   Seats  Diesel  LPG  Petrol  Manual  Fourth & Above  \
# 829  -0.7143 -1.3154 -0.0883  0       0    1       1       0
# 2535 -0.6279 -0.4845 -0.0883  1       0    0       1       0
# 1708 0.5929  0.7198  -0.0883  1       0    0       0       0
# 1589 1.5339  -0.6171 -0.0644  1       0    0       1       0
# 1536 -0.0344 -0.1505 -0.0883  1       0    0       1       0
#
#       Second  Third
# 829   0       0
# 2535  0       0
# 1708  0       0
# 1589  0       0
# 1536  0       0

# %%
# y_train = df_train.pop('Price')
# X_train = df_train

# %%
# X_train = X_train[['Year', 'Engine', 'Power']]

# %%
# X_train.dropna()

# %%
X_train[X_train.replace([np.inf, -np.inf], np.nan).notnull().all(axis=1)]
# Out:
#                                                      Name    Year  \
# 829   Toyota Etios Liva G                                 -0.4262
# 2535  Maruti Swift Dzire Vdi BSIV                         0.8148
# 1708  Audi Q3 35 TDI Quattro Premium Plus                 0.8148
# 1589  Mahindra Bolero ZLX                                 -0.1160
# 1536  Volkswagen Vento Diesel Highline                    -0.7365
# ...                                ...                        ...
# 2347  Ford Ecosport 1.5 DV5 MT Trend                      -0.1160
# 1608  Maruti Wagon R AMT VXI                              0.8148
# 2541  Mercedes-Benz E-Class 2015-2017 E350 CDI Avantgrade 1.4353
# 2575  Chevrolet Tavera LS B3 10 Seats BSIII               0.5045
# 3240  Maruti Swift LXI                                    -0.1160
#
#       Kilometers_Driven  Mileage  Engine   Power   Seats  Diesel  LPG  Petrol  \
# 829  -0.2601            0.0471   -0.7143 -1.3154 -0.0883  0       0    1
# 2535 0.0793             0.2646   -0.6279 -0.4845 -0.0883  1       0    0
# 1708 -0.0098            -0.6337  0.5929  0.7198  -0.0883  1       0    0
# 1589 0.0276             -0.4619  1.5339  -0.6171 -0.0644  1       0    0
# 1536 -0.0844            0.5342   -0.0344 -0.1505 -0.0883  1       0    0
# ...      ...               ...       ...     ...     ... ..      ..   ..
# 2347 -0.2050            1.0040   -0.2040 -0.3052 -0.0883  1       0    0
# 1608 0.0761             0.5277   -1.0518 -0.5620 -0.0883  0       0    1
# 2541 -0.3291            -1.1056  2.3206  1.6643  -0.0883  1       0    0
# 2575 0.5187             -0.7141  1.4932  -0.4159 -0.0286  1       0    0
# 3240 0.0018             0.1123   -0.7143 -0.3507 -0.0883  0       0    1
#
#       Manual  Fourth & Above  Second  Third
# 829   1       0               0       0
# 2535  1       0               0       0
# 1708  0       0               0       0
# 1589  1       0               0       0
# 1536  1       0               0       0
# ...  ..      ..              ..      ..
# 2347  1       0               1       0
# 1608  0       0               0       0
# 2541  0       0               0       0
# 2575  1       0               0       0
# 3240  1       0               0       0
#
# [2799 rows x 14 columns]

# %%
# # Add a constant
# X_train_3c = sm.add_constant(X_train)

# # Create a third fitted model
# lr_3 = sm.OLS(y_train, X_train_3c).fit()
X_train=X_train.drop("Name", axis='columns')
X_test=X_test.drop("Name", axis="columns")

# %%
X_test
# Out:
#         Year  Kilometers_Driven  Mileage  Engine   Power   Seats  Diesel  LPG  \
# 122  1.4353  -0.4269            0.8518   -0.0616 0.1036  -0.0883  1       0
# 188  -0.4262 0.0190             0.9214   -0.0616 0.1049  -0.0883  1       0
# 505  -1.0468 0.2258             -0.0617  -0.6279 -0.4721 -0.0883  1       0
# 984  -0.4262 0.0125             0.9562   0.6387  0.8210  -0.0883  1       0
# 2984 0.8148  -0.4118            0.0906   -0.7143 -0.3507 -0.0883  0       0
# ...     ...      ...               ...       ...     ...     ... ..      ..
# 2039 -1.0468 0.0931             0.4951   -0.7143 -0.4282 -0.0883  0       0
# 857  0.5045  0.1137             0.9214   -0.0616 0.1049  -0.0883  1       0
# 511  -1.3570 0.1760             -0.0356  -0.9025 -0.6171 -0.0883  0       0
# 928  -0.7365 -0.1060            -0.1269  -0.7126 -0.4721 -0.0883  0       0
# 3091 0.5045  -0.3859            -0.2792  -1.3942 -0.9309 -0.0525  0       0
#
#       Petrol  Manual  Fourth & Above  Second  Third
# 122   0       1       0               0       0
# 188   0       1       0               0       0
# 505   0       1       0               1       0
# 984   0       0       0               0       0
# 2984  1       1       0               0       0
# ...  ..      ..      ..              ..      ..
# 2039  1       1       0               0       0
# 857   0       1       0               0       0
# 511   1       1       0               0       0
# 928   1       1       0               0       0
# 3091  1       1       0               0       0
#
# [700 rows x 13 columns]

# %%
X_train
# Out:
#         Year  Kilometers_Driven  Mileage  Engine   Power   Seats  Diesel  LPG  \
# 829  -0.4262 -0.2601            0.0471   -0.7143 -1.3154 -0.0883  0       0
# 2535 0.8148  0.0793             0.2646   -0.6279 -0.4845 -0.0883  1       0
# 1708 0.8148  -0.0098            -0.6337  0.5929  0.7198  -0.0883  1       0
# 1589 -0.1160 0.0276             -0.4619  1.5339  -0.6171 -0.0644  1       0
# 1536 -0.7365 -0.0844            0.5342   -0.0344 -0.1505 -0.0883  1       0
# ...      ...     ...               ...       ...     ...     ... ..      ..
# 2347 -0.1160 -0.2050            1.0040   -0.2040 -0.3052 -0.0883  1       0
# 1608 0.8148  0.0761             0.5277   -1.0518 -0.5620 -0.0883  0       0
# 2541 1.4353  -0.3291            -1.1056  2.3206  1.6643  -0.0883  1       0
# 2575 0.5045  0.5187             -0.7141  1.4932  -0.4159 -0.0286  1       0
# 3240 -0.1160 0.0018             0.1123   -0.7143 -0.3507 -0.0883  0       0
#
#       Petrol  Manual  Fourth & Above  Second  Third
# 829   1       1       0               0       0
# 2535  0       1       0               0       0
# 1708  0       0       0               0       0
# 1589  0       1       0               0       0
# 1536  0       1       0               0       0
# ...  ..      ..      ..              ..      ..
# 2347  0       1       0               1       0
# 1608  1       0       0               0       0
# 2541  0       0       0               0       0
# 2575  0       1       0               0       0
# 3240  1       1       0               0       0
#
# [2799 rows x 13 columns]

# %%
y_test
# Out:
# 122    0.1195
# 188    -0.4450
# 505    -0.5339
# 984    0.7018
# 2984   -0.5294
#          ...
# 2039   -0.6050
# 857    -0.2218
# 511    -0.6494
# 928    -0.6503
# 3091   -0.6450
# Name: Price, Length: 700, dtype: float64

# %%
#RFE
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
from xgboost import XGBRegressor
xgb_model = XGBRegressor()
xgb_model.fit(X_train, y_train)
xgb_model.score(X_test, y_test)
y_pred=xgb_model.predict(X_test)
# y_test['predictions'] = xgb_model.predict(X_test)
# y_test.to_csv('submission.csv')
# preds=xgb_model.predict(X_test)
# accuracy = float(np.sum(preds==y_test))/y_test.shape[0]
# print("accuracy: %f" % (accuracy))

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.datasets import make_regression
regr = AdaBoostRegressor(random_state=20, n_estimators=100)
regr.fit(X_train, y_train)
regr.score(X_test, y_test)
# Out:
# 0.5891774805175081

# %%
# save the model to disk
import pickle
filename = 'part1_model.sav'
pickle.dump(xgb_model, open(filename, 'wb'))

# %%
data1=pd.read_csv(r'test_data.csv')

# %%
# Loading the model 
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_train, y_train)
print("Train Accuracy : ", result)
# Out:
# Train Accuracy :  0.9965594643911154

# %%
# Loading the model 
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, y_test)
print("Test Accuracy : ", result)
# Out:
# Test Accuracy :  0.8398659271413729

# %%
model=pickle.load(open(filename,'rb'))
df_test = pd.read_csv('test_data.csv')
df_test
# df_test['Price']=model.predict(df_test)
# Out:
#                                  Name   Location  Year  Kilometers_Driven  \
# 0     Mahindra XUV500 W6 2WD           Kochi      2017  41290
# 1     BMW 5 Series 520d Luxury Line    Delhi      2013  65000
# 2     Toyota Corolla Altis 1.8 G       Bangalore  2016  16471
# 3     Hyundai i20 Asta 1.4 CRDi        Pune       2015  54339
# 4     Mahindra KUV 100 mFALCON G80 K2  Hyderabad  2016  24025
# ...                               ...        ...   ...    ...
# 2515  Maruti Swift VDI                 Delhi      2014  27365
# 2516  Hyundai Xcent 1.1 CRDi S         Jaipur     2015  100000
# 2517  Mahindra Xylo D4 BSIV            Jaipur     2012  55000
# 2518  Maruti Wagon R VXI               Kolkata    2013  46000
# 2519  Chevrolet Beat Diesel            Hyderabad  2011  47000
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  \
# 0     Diesel    Manual       Second     16.0 kmpl   2179 CC  140 bhp
# 1     Diesel    Automatic    First      22.48 kmpl  1995 CC  190 bhp
# 2     Petrol    Manual       Second     14.28 kmpl  1798 CC  138.03 bhp
# 3     Diesel    Manual       Second     22.54 kmpl  1396 CC  88.73 bhp
# 4     Petrol    Manual       First      18.15 kmpl  1198 CC  82 bhp
# ...      ...       ...         ...             ...      ...     ...
# 2515  Diesel    Manual       First      28.4 kmpl   1248 CC  74 bhp
# 2516  Diesel    Manual       First      24.4 kmpl   1120 CC  71 bhp
# 2517  Diesel    Manual       Second     14.0 kmpl   2498 CC  112 bhp
# 2518  Petrol    Manual       First      18.9 kmpl   998 CC   67.1 bhp
# 2519  Diesel    Manual       First      25.44 kmpl  936 CC   57.6 bhp
#
#       Seats   New_Price
# 0    7.0000  NaN
# 1    5.0000  67.87 Lakh
# 2    5.0000  20.48 Lakh
# 3    5.0000  NaN
# 4    6.0000  NaN
# ...     ...  ...
# 2515 5.0000  7.88 Lakh
# 2516 5.0000  NaN
# 2517 8.0000  NaN
# 2518 5.0000  NaN
# 2519 5.0000  NaN
#
# [2520 rows x 12 columns]

# %%
df_test = dummies('Fuel_Type',df_test)
df_test = dummies('Transmission',df_test)
df_test = dummies('Owner_Type',df_test)

# %%
name=df_test["Name"]
df_test=df_test.drop(['Name', 'Location','New_Price', 'Electric'], axis="columns")

# %%
df_test['Mileage'] = df_test['Mileage'].apply(lambda x: str(x).replace('kmpl', '').replace('km/kg', '')).astype(float)



df_test['Engine'] = df_test['Engine'].apply(lambda x: str(x).replace('CC', '')).astype(float)

df_test['Power'] = df_test['Power'].apply(lambda x: str(x).replace('bhp', '').replace('null ', '0')).astype(float)

df_test
# Out:
#       Year  Kilometers_Driven  Mileage    Engine    Power  Seats  Diesel  LPG  \
# 0     2017  41290             16.0000  2179.0000 140.0000 7.0000  1       0
# 1     2013  65000             22.4800  1995.0000 190.0000 5.0000  1       0
# 2     2016  16471             14.2800  1798.0000 138.0300 5.0000  0       0
# 3     2015  54339             22.5400  1396.0000 88.7300  5.0000  1       0
# 4     2016  24025             18.1500  1198.0000 82.0000  6.0000  0       0
# ...    ...    ...                 ...        ...     ...     ... ..      ..
# 2515  2014  27365             28.4000  1248.0000 74.0000  5.0000  1       0
# 2516  2015  100000            24.4000  1120.0000 71.0000  5.0000  1       0
# 2517  2012  55000             14.0000  2498.0000 112.0000 8.0000  1       0
# 2518  2013  46000             18.9000  998.0000  67.1000  5.0000  0       0
# 2519  2011  47000             25.4400  936.0000  57.6000  5.0000  1       0
#
#       Petrol  Manual  Fourth & Above  Second  Third
# 0     0       1       0               1       0
# 1     0       0       0               0       0
# 2     1       1       0               1       0
# 3     0       1       0               1       0
# 4     1       1       0               0       0
# ...  ..      ..      ..              ..      ..
# 2515  0       1       0               0       0
# 2516  0       1       0               0       0
# 2517  0       1       0               1       0
# 2518  1       1       0               0       0
# 2519  0       1       0               0       0
#
# [2520 rows x 13 columns]

# %%
df_test['Price']=model.predict(df_test)

# %%
name
# Out:
# 0       Mahindra XUV500 W6 2WD
# 1       BMW 5 Series 520d Luxury Line
# 2       Toyota Corolla Altis 1.8 G
# 3       Hyundai i20 Asta 1.4 CRDi
# 4       Mahindra KUV 100 mFALCON G80 K2
#                      ...
# 2515    Maruti Swift VDI
# 2516    Hyundai Xcent 1.1 CRDi S
# 2517    Mahindra Xylo D4 BSIV
# 2518    Maruti Wagon R VXI
# 2519    Chevrolet Beat Diesel
# Name: Name, Length: 2520, dtype: object

# %%
df_test
# Out:
#       Year  Kilometers_Driven  Mileage    Engine    Power  Seats  Diesel  LPG  \
# 0     2017  41290             16.0000  2179.0000 140.0000 7.0000  1       0
# 1     2013  65000             22.4800  1995.0000 190.0000 5.0000  1       0
# 2     2016  16471             14.2800  1798.0000 138.0300 5.0000  0       0
# 3     2015  54339             22.5400  1396.0000 88.7300  5.0000  1       0
# 4     2016  24025             18.1500  1198.0000 82.0000  6.0000  0       0
# ...    ...    ...                 ...        ...     ...     ... ..      ..
# 2515  2014  27365             28.4000  1248.0000 74.0000  5.0000  1       0
# 2516  2015  100000            24.4000  1120.0000 71.0000  5.0000  1       0
# 2517  2012  55000             14.0000  2498.0000 112.0000 8.0000  1       0
# 2518  2013  46000             18.9000  998.0000  67.1000  5.0000  0       0
# 2519  2011  47000             25.4400  936.0000  57.6000  5.0000  1       0
#
#       Petrol  Manual  Fourth & Above  Second  Third  Price
# 0     0       1       0               1       0     2.8357
# 1     0       0       0               0       0     2.8776
# 2     1       1       0               1       0     2.8357
# 3     0       1       0               1       0     2.8357
# 4     1       1       0               0       0     2.8876
# ...  ..      ..      ..              ..      ..        ...
# 2515  0       1       0               0       0     2.8876
# 2516  0       1       0               0       0     2.8876
# 2517  0       1       0               1       0     2.8357
# 2518  1       1       0               0       0     2.8876
# 2519  0       1       0               0       0     2.8876
#
# [2520 rows x 14 columns]

# %%
df_sub = df_test.drop(columns=["Year", "Kilometers_Driven", "Mileage","Engine","Power","Seats","Diesel","LPG","Petrol","Manual","Fourth & Above","Second","Third"], axis = 1)
df_sub["Name"]=name

# %%
df_sub
# Out:
#       Price                             Name
# 0    2.8357  Mahindra XUV500 W6 2WD
# 1    2.8776  BMW 5 Series 520d Luxury Line
# 2    2.8357  Toyota Corolla Altis 1.8 G
# 3    2.8357  Hyundai i20 Asta 1.4 CRDi
# 4    2.8876  Mahindra KUV 100 mFALCON G80 K2
# ...     ...                              ...
# 2515 2.8876  Maruti Swift VDI
# 2516 2.8876  Hyundai Xcent 1.1 CRDi S
# 2517 2.8357  Mahindra Xylo D4 BSIV
# 2518 2.8876  Maruti Wagon R VXI
# 2519 2.8876  Chevrolet Beat Diesel
#
# [2520 rows x 2 columns]

# %%
df_sub.to_csv("part1_prediction.csv", index=False)
